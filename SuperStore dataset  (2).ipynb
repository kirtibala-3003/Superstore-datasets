# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Loading The Dataset

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Superstore Datasets/Sample - Superstore.csv', encoding='ISO-8859-1')
dataset
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# # Overview
# With growing demands and cut-throat competitions in the market, a Superstore Giant is seeking your knowledge in understanding what works best for them. They would like to understand which products, regions, categories and customer segments they should target or avoid.

# %% [markdown]
# # Full Summary Of The Data Frame

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# - Row ID => Unique ID for each row.
# - Order ID => Unique Order ID for each Customer.
# - Order Date => Order Date of the product.
# - Ship Date => Shipping Date of the Product.
# - Ship Mode=> Shipping Mode specified by the
#   Customer.
# - Customer ID => Unique ID to identify each
#  Customer.
# - Customer Name => Name of the Customer.
# - Segment => The segment where the Customer belongs.
# - Country => Country of residence of the
#   Customer.
# - City => City of residence of of the Customer.
# - State => State of residence of the Customer.
# - Postal Code => Postal Code of every Customer.
# - Region => Region where the Customer belong.
# - Product ID => Unique ID of the Product.
# - Category => Category of the product ordered.
# - Sub-Category => Sub-Category of the product
#    ordered.
# - Product Name => Name of the Product
# - Sales => Sales of the Product.
# - Quantity => Quantity of the Product.
# - Discount => Discount provided.
# - Profit => Profit/Loss incurred.

# %% [markdown]
# # Data Cleaning

# %%
dataset['Order Date'] = pd.to_datetime(dataset['Order Date'])
dataset['Ship Date'] = pd.to_datetime(dataset['Ship Date'])

# %% [markdown]
# # Check The Missing Values

# %%
dataset.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# # Check the dataset for duplicate and dropping element

# %%
dataset.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Shape of the Dataset

# %%
dataset.shape
# Out:
# (9994, 21)

# %% [markdown]
# # Value Counts of each columns in the Dataset

# %%
dataset['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
dataset['Segment'].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
dataset['Country'].value_counts()  # as in the dataset all are from same country so this column is needless
# Out:
# Country
# United States    9994
# Name: count, dtype: int64

# %%
dataset['Customer ID'].value_counts()
# Out:
# Customer ID
# WB-21850    37
# MA-17560    34
# JL-15835    34
# PP-18955    34
# CK-12205    32
#             ..
# AO-10810     1
# LD-16855     1
# JR-15700     1
# CJ-11875     1
# RE-19405     1
# Name: count, Length: 793, dtype: int64

# %%
dataset['Customer Name'].value_counts()
# Out:
# Customer Name
# William Brown          37
# Matt Abelman           34
# John Lee               34
# Paul Prost             34
# Chloris Kastensmidt    32
#                        ..
# Anthony O'Donnell       1
# Lela Donovan            1
# Jocasta Rupert          1
# Carl Jackson            1
# Ricardo Emerson         1
# Name: count, Length: 793, dtype: int64

# %%
dataset['State'].value_counts()
# Out:
# State
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
dataset['City'].value_counts()
# Out:
# City
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
#                 ...
# Abilene            1
# Montebello         1
# Kissimmee          1
# Danbury            1
# Springdale         1
# Name: count, Length: 531, dtype: int64

# %%
dataset['Postal Code'].value_counts()
# Out:
# Postal Code
# 10035    263
# 10024    230
# 10009    229
# 94122    203
# 10011    193
#         ...
# 61761      1
# 79605      1
# 72762      1
# 8401       1
# 95616      1
# Name: count, Length: 631, dtype: int64

# %%
dataset['Region'].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
dataset['Product ID'].value_counts()
# Out:
# Product ID
# OFF-PA-10001970    19
# TEC-AC-10003832    18
# FUR-FU-10004270    16
# FUR-CH-10002647    15
# FUR-CH-10001146    15
#                    ..
# TEC-MA-10004552     1
# TEC-MA-10003589     1
# OFF-AP-10003099     1
# TEC-PH-10002645     1
# OFF-ST-10001627     1
# Name: count, Length: 1862, dtype: int64

# %%
dataset['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
dataset['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
dataset['Product Name'].value_counts()
# Out:
# Product Name
# Staple envelope                                                            48
# Staples                                                                    46
# Easy-staple paper                                                          46
# Avery Non-Stick Binders                                                    20
# Staples in misc. colors                                                    19
#                                                                            ..
# Xiaomi Mi3                                                                  1
# Sanitaire Vibra Groomer IR Commercial Upright Vacuum, Replacement Belts     1
# Holmes Harmony HEPA Air Purifier for 17 x 20 Room                           1
# Avery Hi-Liter Pen Style Six-Color Fluorescent Set                          1
# Eldon Jumbo ProFile Portable File Boxes Graphite/Black                      1
# Name: count, Length: 1850, dtype: int64

# %%
dataset['Quantity'].value_counts()
# Out:
# Quantity
# 3     2409
# 2     2402
# 5     1230
# 4     1191
# 1      899
# 7      606
# 6      572
# 9      258
# 8      257
# 10      57
# 11      34
# 14      29
# 13      27
# 12      23
# Name: count, dtype: int64

# %%
dataset['Shipping Delay'] = (dataset['Ship Date'] - dataset['Order Date']).dt.days
dataset['Shipping Delay']
# Out:
# 0       3
# 1       3
# 2       4
# 3       7
# 4       7
#        ..
# 9989    2
# 9990    5
# 9991    5
# 9992    5
# 9993    5
# Name: Shipping Delay, Length: 9994, dtype: int64

# %%
dataset.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Delay'],
#       dtype='object')

# %%
dataset['year']= dataset['Ship Date'].dt.year
dataset['year']
# Out:
# 0       2016
# 1       2016
# 2       2016
# 3       2015
# 4       2015
#         ...
# 9989    2014
# 9990    2017
# 9991    2017
# 9992    2017
# 9993    2017
# Name: year, Length: 9994, dtype: int32

# %%
dataset['month']= dataset['Ship Date'].dt.month
dataset['month']
# Out:
# 0       11
# 1       11
# 2        6
# 3       10
# 4       10
#         ..
# 9989     1
# 9990     3
# 9991     3
# 9992     3
# 9993     5
# Name: month, Length: 9994, dtype: int32

# %%
dataset['Weekday_order']= dataset['Order Date'].dt.day_name()
dataset['Weekday_order']
# Out:
# 0        Tuesday
# 1        Tuesday
# 2         Sunday
# 3         Sunday
# 4         Sunday
#           ...
# 9989     Tuesday
# 9990      Sunday
# 9991      Sunday
# 9992      Sunday
# 9993    Thursday
# Name: Weekday_order, Length: 9994, dtype: object

# %%
dataset['quarter']= dataset['Ship Date'].dt.quarter .astype(str)
dataset['quarter']
# Out:
# 0       4
# 1       4
# 2       2
# 3       4
# 4       4
#        ..
# 9989    1
# 9990    1
# 9991    1
# 9992    1
# 9993    2
# Name: quarter, Length: 9994, dtype: object

# %%
dataset['Weekday_ship']= dataset['Ship Date'].dt.day_name()
dataset['Weekday_ship']
# Out:
# 0         Friday
# 1         Friday
# 2       Thursday
# 3         Sunday
# 4         Sunday
#           ...
# 9989    Thursday
# 9990      Friday
# 9991      Friday
# 9992      Friday
# 9993     Tuesday
# Name: Weekday_ship, Length: 9994, dtype: object

# %%
del_column = ['Row ID','Order ID','Customer Name','Country','Postal Code','Product ID','Order Date','Ship Date']
dataset.drop(del_column,axis=1,inplace=True)

# %%
dataset.describe()
# Out:
#               Sales     Quantity     Discount       Profit  Shipping Delay  \
# count   9994.000000  9994.000000  9994.000000  9994.000000     9994.000000
# mean     229.858001     3.789574     0.156203    28.656896        3.958175
# std      623.245101     2.225110     0.206452   234.260108        1.747567
# min        0.444000     1.000000     0.000000 -6599.978000        0.000000
# 25%       17.280000     2.000000     0.000000     1.728750        3.000000
# 50%       54.490000     3.000000     0.200000     8.666500        4.000000
# 75%      209.940000     5.000000     0.200000    29.364000        5.000000
# max    22638.480000    14.000000     0.800000  8399.976000        7.000000
#
#               year        month
# count  9994.000000  9994.000000
# mean   2015.737442     7.743146
# std       1.126141     3.340476
# min    2014.000000     1.000000
# 25%    2015.000000     5.000000
# 50%    2016.000000     9.000000
# 75%    2017.000000    11.000000
# ...

# %%
dataset[dataset['Sales']<1]  # discount = 0.8
# Out:
#            Ship Mode Customer ID      Segment           City         State  \
# 2106        Same Day    HG-14965    Corporate       Mesquite         Texas
# 2761     First Class    NK-18490  Home Office  San Francisco    California
# 4101  Standard Class    ZC-21910     Consumer        Houston         Texas
# 4711        Same Day    JO-15280     Consumer   Philadelphia  Pennsylvania
# 7548  Standard Class    CM-12715    Corporate     Huntsville         Texas
# 8033     First Class    MV-17485     Consumer        Houston         Texas
# 8658  Standard Class    KB-16600    Corporate        Chicago      Illinois
# 9292        Same Day    RS-19765    Corporate           Waco         Texas
#
#        Region         Category Sub-Category  \
# 2106  Central  Office Supplies      Binders
# 2761     West       Technology  Accessories
# 4101  Central  Office Supplies   Appliances
# 4711     East  Office Supplies      Binders
# 7548  Central  Office Supplies      Binders
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Ship Mode       9994 non-null   object
#  1   Customer ID     9994 non-null   object
#  2   Segment         9994 non-null   object
#  3   City            9994 non-null   object
#  4   State           9994 non-null   object
#  5   Region          9994 non-null   object
#  6   Category        9994 non-null   object
#  7   Sub-Category    9994 non-null   object
#  8   Product Name    9994 non-null   object
#  9   Sales           9994 non-null   float64
#  10  Quantity        9994 non-null   int64
#  11  Discount        9994 non-null   float64
#  12  Profit          9994 non-null   float64
#  13  Shipping Delay  9994 non-null   int64
#  14  year            9994 non-null   int32
#  15  month           9994 non-null   int32
#  16  Weekday_order   9994 non-null   object
# ...

# %% [markdown]
# # Data Visualization of the Dataset

# %%
weekday_order_freq = dataset['Weekday_order'].value_counts().index

# Create the countplot with weekdays ordered by frequency
plt.figure(figsize=(10, 6))
sns.countplot(x='Weekday_order', data=dataset, palette='Set1', order=weekday_order_freq)

# Add title and labels
plt.title('Frequency of Orders by Day of the Week (Ordered by Frequency)')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Orders')

# Show the plot
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()
# Out:
# <ipython-input-36-904028ac03d6>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Weekday_order', data=dataset, palette='Set1', order=weekday_order_freq)

# %%
product_group = dataset.groupby(["Product Name"]).sum()["Sales"]
top_selling_products = product_group.sort_values(ascending=False)
top_5_selling_products = pd.DataFrame(top_selling_products[:5])
top_5_selling_products.plot(kind="bar")

# Add a title to the plot
plt.title("Top 5 Profit Products in Superstore")

# Add labels to the x and y axes
plt.xlabel("Product Name")
plt.ylabel("Total Profit")

# Show the plot
plt.show()

# %%
yearly_sales = dataset.groupby('year')['Sales'].sum().reset_index()

plt.figure(figsize=(10, 5))
sns.lineplot(data=yearly_sales, x='year', y='Sales', marker='o', color='b')
plt.title('Yearly Sales Trend')
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Discount', y='Profit', data=dataset, palette='Set1')
plt.title('Relationship Between Discount and Profit')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.show()
# Out:
# <ipython-input-40-4e73918a9cc4>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x='Discount', y='Profit', data=dataset, palette='Set1')

# %%
dataset.hist(bins=50 ,figsize=(20,15))
plt.show()

# %%
figsize=(15,10)
sns.pairplot(dataset,hue='Sub-Category')
